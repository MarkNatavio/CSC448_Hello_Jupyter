# %%
print('Hello Jupyter!')
# Out:
# Hello Jupyter!

# %% [markdown]
# Sorrounding text with _ or * creates Italics, like such _italics_

# %% [markdown]
# # Header
# ## Header
# ### Header
# #### Header
# ##### Header

# %% [markdown]
# * item 1
#     * sub item
# * item 2
